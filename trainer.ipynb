# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D,
    Activation, Flatten,
    Dense, Dropout
)

# ------------------------------------------------------
# PARAMETERS & DIRECTORY SETUP
# ------------------------------------------------------
dataset_dir = r"C:\Users\benny\Sonogram\dataset" 
classes     = ['normal', 'benign', 'malignant']
class_to_label = {cls: i for i, cls in enumerate(classes)}

img_height, img_width = 150, 150
batch_size = 16
epochs     = 30
learning_rate = 1e-4

# ------------------------------------------------------
# COLLECT IMAGE PATHS & LABELS
# ------------------------------------------------------
all_paths = []
all_labels = []
for cls in classes:
    folder = os.path.join(dataset_dir, cls)
    if not os.path.isdir(folder):
        print(f"Warning: class folder missing: {folder}")
        continue
    for fname in os.listdir(folder):
        # skip mask files or non-image
        if '_mask' in fname.lower(): 
            continue
        ext = os.path.splitext(fname)[1].lower()
        if ext not in {'.jpg', '.jpeg', '.png'}:
            continue
        all_paths.append(os.path.join(folder, fname))
        all_labels.append(class_to_label[cls])

print(f"Found {len(all_paths)} total images.")

# ------------------------------------------------------
# TRAIN/VAL/TEST SPLIT
# ------------------------------------------------------
data = list(zip(all_paths, all_labels))
np.random.shuffle(data)
paths_shuffled, labels_shuffled = zip(*data)

n = len(paths_shuffled)
n_train = int(0.7 * n)
n_val   = int(0.15 * n)

train_paths = paths_shuffled[:n_train]
train_labels= labels_shuffled[:n_train]

val_paths   = paths_shuffled[n_train:n_train+n_val]
val_labels  = labels_shuffled[n_train:n_train+n_val]

test_paths  = paths_shuffled[n_train+n_val:]
test_labels = labels_shuffled[n_train+n_val:]

print(f"Train: {len(train_paths)}, Val: {len(val_paths)}, Test: {len(test_paths)}")

# ------------------------------------------------------
# DATASET CREATION
# ------------------------------------------------------
def load_and_preprocess(path, label):
    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [img_height, img_width])
    img = img / 255.0
    return img, label

def make_dataset(paths, labels, shuffle=True):
    ds = tf.data.Dataset.from_tensor_slices((list(paths), list(labels)))
    ds = ds.map(load_and_preprocess, 
                num_parallel_calls=tf.data.experimental.AUTOTUNE)
    if shuffle:
        ds = ds.shuffle(buffer_size=len(paths))
    ds = ds.batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)
    return ds

train_ds = make_dataset(train_paths, train_labels, shuffle=True)
val_ds   = make_dataset(val_paths, val_labels, shuffle=False)
test_ds  = make_dataset(test_paths, test_labels, shuffle=False)

# ------------------------------------------------------
# MODEL DEFINITION (3‑channel input)
# ------------------------------------------------------
model = Sequential([
    Input(shape=(img_height, img_width, 3)),
    Conv2D(32, (3, 3)), Activation('relu'), MaxPooling2D(),
    Conv2D(64, (3, 3)), Activation('relu'), MaxPooling2D(),
    Conv2D(128, (3, 3)), Activation('relu'), MaxPooling2D(),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(len(classes), activation='softmax')
])

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate),
    metrics=['accuracy']
)

model.summary()

# ------------------------------------------------------
# TRAIN
# ------------------------------------------------------
history = model.fit(
    train_ds,
    epochs=epochs,
    validation_data=val_ds
)

# ------------------------------------------------------
# EVALUATE & SAVE
# ------------------------------------------------------
test_loss, test_acc = model.evaluate(test_ds)
print(f"Test Accuracy: {test_acc:.4f}")

model.save("sonogram_tumor_detection_model.h5")
print("Model saved as sonogram_tumor_detection_model.h5")
# Out:
# Found 780 total images.
# Train: 546, Val: 117, Test: 117
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None,
30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 232ms/step - accuracy: 0.9975 - loss: 0.0350 - val_accuracy: 0.6838 - val_loss: 1.1216
# Epoch 25/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 242ms/step - accuracy: 0.9865 - loss: 0.0446 - val_accuracy: 0.7265 - val_loss: 1.1750
# Epoch 26/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 237ms/step - accuracy: 0.9987 - loss: 0.0242 - val_accuracy: 0.7094 - val_loss: 1.3220
# Epoch 27/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 237ms/step - accuracy: 0.9957 - loss: 0.0192 - val_accuracy: 0.6838 - val_loss: 1.3215
# Epoch 28/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 258ms/step - accuracy: 0.9997 - loss: 0.0133 - val_accuracy: 0.6496 - val_loss: 1.3605
# Epoch 29/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 258ms/step - accuracy: 0.9921 - loss: 0.0251 - val_accuracy: 0.6923 - val_loss: 1.3501
# Epoch 30/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 241ms/step - accuracy: 0.9919 - loss: 0.0301 - val_accuracy: 0.6752 - val_loss: 1.3203
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.7605 - loss: 0.9792
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Accuracy: 0.7436
# Model saved as sonogram_tumor_detection_model.h5

# %%
# predict.py

import os
import numpy as np
import tensorflow as tf

# ──────────────────────────────────────────────────────────────────────────────
# SILENCE TF LOGS
# ──────────────────────────────────────────────────────────────────────────────
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')

# ──────────────────────────────────────────────────────────────────────────────
# CONFIGURATION
# ──────────────────────────────────────────────────────────────────────────────
MODEL_PATH  = "sonogram_tumor_detection_model.h5"
TEST_FOLDER = "datatotest"
IMG_SIZE    = (150, 150)
CLASSES     = ["normal", "benign", "malignant"]
VALID_EXTS  = {".jpg", ".jpeg", ".png"}
# ──────────────────────────────────────────────────────────────────────────────

def preprocess_rgb(path):
    """
    Reads and decodes a 3‑channel JPEG/PNG,
    resizes to IMG_SIZE, scales to [0,1],
    returns a (H, W, 3) float32 tensor.
    """
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, IMG_SIZE) / 255.0
    return img

def main():
    # 1) Load the model (inference-only)
    if not os.path.exists(MODEL_PATH):
        print(f"ERROR: Model file not found at '{MODEL_PATH}'")
        return
    model = tf.keras.models.load_model(MODEL_PATH, compile=False)

    # 2) Collect all valid test images
    if not os.path.isdir(TEST_FOLDER):
        print(f"ERROR: Test folder not found at '{TEST_FOLDER}'")
        return
    files = sorted(f for f in os.listdir(TEST_FOLDER)
                   if os.path.splitext(f)[1].lower() in VALID_EXTS)
    if not files:
        print("No images to process.")
        return
    paths = [os.path.join(TEST_FOLDER, f) for f in files]

    # 3) Preprocess all into a single batch of shape (N, H, W, 3)
    imgs = [preprocess_rgb(p) for p in paths]
    batch = tf.stack(imgs, axis=0)  # shape: (N, 150, 150, 3)

    # 4) Single eager call
    preds = model(batch, training=False).numpy()  # shape: (N, 3)

    # 5) Print results and compute (optional) weighted accuracy
    sum_conf_all = 0.0
    sum_conf_corr = 0.0

    for fname, pred in zip(files, preds):
        idx   = np.argmax(pred)
        label = CLASSES[idx]
        conf  = float(pred[idx])

        # assuming you know the true class folder name matches CLASSES
        true_label = fname.split(os.sep)[-1].split()[0]  # e.g. "malignant" or "benign"
        correct = (label == true_label)

        sum_conf_all += conf
        if correct:
            sum_conf_corr += conf

        print(f"{fname:30s} → {label:9s} (confidence: {conf:.4f})")

    if sum_conf_all > 0:
        weighted_acc = sum_conf_corr / sum_conf_all
        print(f"\nWeighted accuracy: {weighted_acc:.2%}")

if __name__ == "__main__":
    main()
# Out:
# benign (1).png                 → benign    (confidence: 1.0000)
# benign (10).png                → benign    (confidence: 1.0000)
# benign (100).png               → benign    (confidence: 0.9925)
# benign (101).png               → malignant (confidence: 0.7984)
# benign (102).png               → benign    (confidence: 0.9200)
# benign (103).png               → malignant (confidence: 0.9642)
# benign (104).png               → benign    (confidence: 0.9994)
# benign (105).png               → benign    (confidence: 0.9996)
# benign (106).png               → benign    (confidence: 0.9990)
# benign (107).png               → benign    (confidence: 0.9982)
# benign (108).png               → benign    (confidence: 0.9841)
# benign (109).png               → benign    (confidence: 0.9999)
# benign (11).png                → benign    (confidence: 1.0000)
# benign (110).png               → benign    (confidence: 1.0000)
# benign (111).png               → benign    (confidence: 0.9798)
# benign (112).png               → benign    (confidence: 0.9849)
# benign (113).png               → benign    (confidence: 0.9771)
# benign (114).png               → benign    (confidence: 0.9993)
# benign (115).png               → benign    (confidence: 0.9997)
# benign (116).png               → benign    (confidence: 0.9999)
# benign (117).png               → benign    (confidence: 0.9124)
# benign (118).png               → benign    (confidence: 0.9975)
# benign (119).png               → benign    (confidence: 0.9999)
# benign (12).png                → benign    (confidence: 1.0000)
# benign (120).png               → normal    (confidence: 0.5997)
# benign (121).png               → benign    (confidence: 0.9994)
# benign (122).png               → benign    (confidence: 0.9999)
# benign (123).png               → benign    (confidence: 1.0000)
# benign (124).png               → benign    (confidence: 0.9996)
# benign (125).png               → benign    (confidence: 0.9997)
# benign (126).png               → benign    (confidence: 1.0000)
# benign (127).png               → benign    (confidence: 0.9990)
# benign (128).png               → benign    (confidence: 0.9942)
# benign (129).png               → benign    (confidence: 0.9997)
# benign (13).png                → benign    (confidence: 0.9991)
# benign (130).png               → benign    (confidence: 0.9999)
# benign (131).png               → malignant (confidence: 0.9850)
# benign (132).png               → benign    (confidence: 1.0000)
# benign (133).png               → benign    (confidence: 1.0000)
# benign (134).png               → benign    (confidence: 1.0000)
# benign (135).png               → benign    (confidence: 0.9991)
# benign (136).png               → benign    (confidence: 0.9998)
# benign (137).png               → benign    (confidence: 0.9963)
# benign (138).png               → benign    (confidence: 0.9990)
# benign (139).png               → benign    (confidence: 1.0000)
# benign (14).png                → benign    (confidence: 0.9998)
# benign (140).png               → benign    (confidence: 0.9997)
# benign (141).png               → benign    (confidence: 0.9221)
# benign (142).png               → benign    (confidence: 0.9993)
# benign (143).png               → benign    (confidence: 0.9999)
# benign (144).png               → benign    (confidence: 0.9986)
# benign (145).png               → benign    (confidence: 0.9998)
# benign (146).png               → benign    (confidence: 0.9978)
# benign (147).png               → benign    (confidence: 0.9991)
# benign (148).png               → benign    (confidence: 1.0000)
# benign (149).png               → benign    (confidence: 0.9849)
# benign (15).png                → benign    (confidence: 0.9995)
# benign (150).png               → benign    (confidence: 0.9980)
# benign (151).png               → benign    (confidence: 0.9629)
# benign (152).png               → benign    (confidence: 1.0000)
# benign (153).png               → benign    (confidence: 1.0000)
# benign (154).png               → benign    (confidence: 0.9998)
# benign (155).png               → benign    (confidence: 0.9981)
# benign (156).png               → benign    (confidence: 0.9995)
# benign (157).png               → benign    (confidence: 1.0000)
# benign (158).png               → benign    (confidence: 1.0000)
# benign (159).png               → benign    (confidence: 0.9975)
# benign (16).png                → benign    (confidence: 0.9106)
# benign (160).png               → benign    (confidence: 0.9973)
# benign (161).png               → benign    (confidence: 0.9996)
# benign (162).png               → benign    (confidence: 1.0000)
# benign (163).png               → benign    (confidence: 0.9998)
# benign (164).png               → benign    (confidence: 0.9804)
# benign (165).png               → benign    (confidence: 0.9988)
# benign (166).png               → benign    (confidence: 0.9002)
# benign (167).png               → benign    (confidence: 0.9994)
# benign (168).png               → benign    (confidence: 0.9974)
# benign (169).png               → benign    (confidence: 0.9977)
# benign (17).png                → benign    (confidence: 0.9966)
# benign (170).png               → benign    (confidence: 0.9993)
# benign (171).png               → benign    (confidence: 0.9987)
# benign (172).png               → benign    (confidence: 0.9996)
# benign (173).png               → benign    (confidence: 1.0000)
# benign (174).png               → benign    (confidence: 0.9995)
# benign (175).png               → benign    (confidence: 0.7601)
# benign (176).png               → benign    (confidence: 0.9999)
# benign (177).png               → benign    (confidence: 1.0000)
# benign (178).png               → benign    (confidence: 1.0000)
# benign (179).png               → benign    (confidence: 0.9922)
# benign (18).png                → benign    (confidence: 1.0000)
# benign (180).png               → benign    (confidence: 0.9991)
# benign (181).png               → benign    (confidence: 0.9998)
# benign (182).png               → benign    (confidence: 0.9989)
# benign (183).png               → normal    (confidence: 0.7986)
# benign (184).png               → benign    (confidence: 1.0000)
# benign (185).png               → normal    (confidence: 0.9912)
# benign (186).png               → benign    (confidence: 0.9992)
# benign (187).png               → benign    (confidence: 0.9995)
# benign (188).png               → benign    (confidence: 0.9924)
# benign (189).png               → benign    (confidence: 0.9999)
# benign (19).png                → benign    (confidence: 0.9984)
# benign (190).png               → benign    (confidence: 0.9994)
# benign (191).png               → benign    (confidence: 0.9881)
# benign (192).png               → benign    (confidence: 0.9949)
# benign (193).png               → benign    (confidence: 0.9996)
# benign (194).png               → benign    (confidence: 0.9987)
# benign (195).png               → benign    (confidence: 0.9988)
# benign (196).png               → benign    (confidence: 0.9198)
# benign (197).png               → benign    (confidence: 1.0000)
# benign (198).png               → benign    (confidence: 0.9861)
# benign (199).png               → benign    (confidence: 1.0000)
# benign (2).png                 → benign    (confidence: 0.9991)
# benign (20).png                → benign    (confidence: 0.9998)
# benign (200).png               → benign    (confidence: 1.0000)
# benign (201).png               → benign    (confidence: 0.9993)
# benign (202).png               → benign    (confidence: 0.9864)
# benign (203).png               → benign    (confidence: 0.9997)
# benign (204).png               → benign    (confidence: 1.0000)
# benign (205).png               → benign    (confidence: 1.0000)
# benign (206).png               → benign    (confidence: 0.9983)
# benign (207).png               → benign    (confidence: 0.9993)
# benign (208).png               → benign    (confidence: 1.0000)
# benign (209).png               → benign    (confidence: 1.0000)
# benign (21).png                → benign    (confidence: 0.9972)
# benign (210).png               → benign    (confidence: 1.0000)
# benign (211).png               → benign    (confidence: 0.9955)
# benign (212).png               → normal    (confidence: 0.9407)
# benign (213).png               → benign    (confidence: 0.9988)
# benign (214).png               → benign    (confidence: 0.9999)
# benign (215).png               → benign    (confidence: 0.9995)
# benign (216).png               → benign    (confidence: 1.0000)
# benign (217).png               → benign    (confidence: 1.0000)
# benign (218).png               → benign    (confidence: 1.0000)
# benign (219).png               → normal    (confidence: 0.4904)
# benign (22).png                → benign    (confidence: 1.0000)
# benign (220).png               → benign    (confidence: 0.9449)
# benign (221).png               → benign    (confidence: 1.0000)
# benign (222).png               → benign    (confidence: 0.9996)
# benign (223).png               → benign    (confidence: 1.0000)
# benign (224).png               → benign    (confidence: 0.9883)
# benign (225).png               → benign    (confidence: 0.9999)
# benign (226).png               → benign    (confidence: 1.0000)
# benign (227).png               → benign    (confidence: 0.9999)
# benign (228).png               → benign    (confidence: 0.9940)
# benign (229).png               → benign    (confidence: 0.9957)
# benign (23).png                → benign    (confidence: 0.7360)
# benign (230).png               → benign    (confidence: 1.0000)
# benign (231).png               → benign    (confidence: 1.0000)
# benign (232).png               → benign    (confidence: 1.0000)
# benign (233).png               → benign    (confidence: 0.9999)
# benign (234).png               → benign    (confidence: 0.9999)
# benign (235).png               → benign    (confidence: 0.9998)
# benign (236).png               → benign    (confidence: 0.9989)
# benign (237).png               → benign    (confidence: 1.0000)
# benign (238).png               → benign    (confidence: 1.0000)
# benign (239).png               → normal    (confidence: 0.7253)
# benign (24).png                → benign    (confidence: 1.0000)
# benign (240).png               → benign    (confidence: 0.9993)
# benign (241).png               → benign    (confidence: 0.9990)
# benign (242).png               → benign    (confidence: 0.9989)
# benign (243).png               → benign    (confidence: 0.9950)
# benign (244).png               → benign    (confidence: 1.0000)
# benign (245).png               → benign    (confidence: 1.0000)
# benign (246).png               → benign    (confidence: 0.9991)
# benign (247).png               → benign    (confidence: 0.9998)
# benign (248).png               → benign    (confidence: 1.0000)
# benign (249).png               → benign    (confidence: 1.0000)
# benign (25).png                → benign    (confidence: 0.9999)
# benign (250).png               → benign    (confidence: 0.9994)
# benign (251).png               → benign    (confidence: 1.0000)
# benign (252).png               → benign    (confidence: 0.9998)
# benign (253).png               → benign    (confidence: 0.9265)
# benign (254).png               → benign    (confidence: 0.9962)
# benign (255).png               → benign    (confidence: 0.9985)
# benign (256).png               → benign    (confidence: 1.0000)
# benign (257).png               → benign    (confidence: 1.0000)
# benign (258).png               → normal    (confidence: 0.8629)
# benign (259).png               → benign    (confidence: 0.9918)
# benign (26).png                → benign    (confidence: 0.9994)
# benign (260).png               → benign    (confidence: 0.9999)
# benign (261).png               → benign    (confidence: 0.9949)
# benign (262).png               → benign    (confidence: 1.0000)
# benign (263).png               → benign    (confidence: 1.0000)
# benign (264).png               → benign    (confidence: 1.0000)
# benign (265).png               → benign    (confidence: 1.0000)
# benign (266).png               → benign    (confidence: 0.9974)
# benign (267).png               → benign    (confidence: 0.9999)
# benign (268).png               → benign    (confidence: 1.0000)
# benign (269).png               → benign    (confidence: 0.8716)
# benign (27).png                → benign    (confidence: 1.0000)
# benign (270).png               → benign    (confidence: 0.9996)
# benign (271).png               → benign    (confidence: 0.9994)
# benign (272).png               → malignant (confidence: 0.9070)
# benign (273).png               → benign    (confidence: 0.9998)
# benign (274).png               → benign    (confidence: 1.0000)
# benign (275).png               → benign    (confidence: 0.9998)
# benign (276).png               → benign    (confidence: 0.9998)
# benign (277).png               → benign    (confidence: 0.9991)
# benign (278).png               → benign    (confidence: 0.9999)
# benign (279).png               → benign    (confidence: 0.9994)
# benign (28).png                → benign    (confidence: 0.9999)
# benign (280).png               → benign    (confidence: 0.9965)
# benign (281).png               → benign    (confidence: 0.9996)
# benign (282).png               → benign    (confidence: 1.0000)
# benign (283).png               → benign    (confidence: 0.5360)
# benign (284).png               → benign    (confidence: 1.0000)
# benign (285).png               → benign    (confidence: 1.0000)
# benign (286).png               → benign    (confidence: 1.0000)
# benign (287).png               → benign    (confidence: 0.9992)
# benign (288).png               → benign    (confidence: 0.9995)
# benign (289).png               → benign    (confidence: 0.9999)
# benign (29).png                → benign    (confidence: 0.9984)
# benign (290).png               → benign    (confidence: 1.0000)
# benign (291).png               → benign    (confidence: 0.9999)
# benign (292).png               → benign    (confidence: 0.9999)
# benign (293).png               → benign    (confidence: 0.9981)
# benign (294).png               → benign    (confidence: 0.9997)
# benign (295).png               → benign    (confidence: 0.9999)
# benign (296).png               → benign    (confidence: 0.9999)
# benign (297).png               → benign    (confidence: 0.9999)
# benign (298).png               → benign    (confidence: 1.0000)
# benign (299).png               → benign    (confidence: 0.9998)
# benign (3).png                 → benign    (confidence: 1.0000)
# benign (30).png                → benign    (confidence: 0.9898)
# benign (300).png               → benign    (confidence: 1.0000)
# benign (301).png               → benign    (confidence: 0.9981)
# benign (302).png               → benign    (confidence: 0.9998)
# benign (303).png               → benign    (confidence: 0.9988)
# benign (304).png               → benign    (confidence: 0.9990)
# benign (305).png               → benign    (confidence: 1.0000)
# benign (306).png               → benign    (confidence: 0.9958)
# benign (307).png               → benign    (confidence: 0.9998)
# benign (308).png               → benign    (confidence: 0.9996)
# benign (309).png               → normal    (confidence: 0.4984)
# benign (31).png                → benign    (confidence: 0.9999)
# benign (310).png               → benign    (confidence: 0.9994)
# benign (311).png               → benign    (confidence: 1.0000)
# benign (312).png               → malignant (confidence: 0.9732)
# benign (313).png               → benign    (confidence: 0.9999)
# benign (314).png               → benign    (confidence: 0.9028)
# benign (315).png               → benign    (confidence: 0.9999)
# benign (316).png               → benign    (confidence: 0.9978)
# benign (317).png               → benign    (confidence: 0.9999)
# benign (318).png               → benign    (confidence: 1.0000)
# benign (319).png               → benign    (confidence: 0.9999)
# benign (32).png                → benign    (confidence: 1.0000)
# benign (320).png               → benign    (confidence: 1.0000)
# benign (321).png               → benign    (confidence: 1.0000)
# benign (322).png               → benign    (confidence: 1.0000)
# benign (323).png               → benign    (confidence: 1.0000)
# benign (324).png               → benign    (confidence: 0.9987)
# benign (325).png               → benign    (confidence: 0.9994)
# benign (326).png               → benign    (confidence: 0.9985)
# benign (327).png               → benign    (confidence: 1.0000)
# benign (328).png               → benign    (confidence: 0.9999)
# benign (329).png               → benign    (confidence: 1.0000)
# benign (33).png                → benign    (confidence: 0.9997)
# benign (330).png               → benign    (confidence: 0.9974)
# benign (331).png               → benign    (confidence: 0.9968)
# benign (332).png               → benign    (confidence: 0.9999)
# benign (333).png               → benign    (confidence: 0.9957)
# benign (334).png               → benign    (confidence: 1.0000)
# benign (335).png               → benign    (confidence: 0.9846)
# benign (336).png               → benign    (confidence: 0.9982)
# benign (337).png               → normal    (confidence: 0.6365)
# benign (338).png               → benign    (confidence: 0.9992)
# benign (339).png               → benign    (confidence: 0.9976)
# benign (34).png                → benign    (confidence: 0.9973)
# benign (340).png               → benign    (confidence: 1.0000)
# benign (341).png               → benign    (confidence: 1.0000)
# benign (342).png               → benign    (confidence: 0.9999)
# benign (343).png               → benign    (confidence: 0.9994)
# benign (344).png               → benign    (confidence: 0.9317)
# benign (345).png               → benign    (confidence: 0.9990)
# benign (346).png               → malignant (confidence: 0.6755)
# benign (347).png               → benign    (confidence: 0.9917)
# benign (348).png               → malignant (confidence: 0.4192)
# benign (349).png               → benign    (confidence: 0.6708)
# benign (35).png                → benign    (confidence: 1.0000)
# benign (350).png               → benign    (confidence: 0.9982)
# benign (351).png               → benign    (confidence: 0.8765)
# benign (352).png               → benign    (confidence: 0.9825)
# benign (353).png               → normal    (confidence: 0.6147)
# benign (354).png               → benign    (confidence: 0.9993)
# benign (355).png               → benign    (confidence: 0.9984)
# benign (356).png               → benign    (confidence: 0.8560)
# benign (357).png               → normal    (confidence: 0.8700)
# benign (358).png               → benign    (confidence: 0.9983)
# benign (359).png               → benign    (confidence: 0.9996)
# benign (36).png                → benign    (confidence: 0.8978)
# benign (360).png               → benign    (confidence: 0.9545)
# benign (361).png               → benign    (confidence: 0.9990)
# benign (362).png               → benign    (confidence: 1.0000)
# benign (363).png               → benign    (confidence: 0.9875)
# benign (364).png               → benign    (confidence: 0.9955)
# benign (365).png               → benign    (confidence: 0.9970)
# benign (366).png               → benign    (confidence: 0.9998)
# benign (367).png               → benign    (confidence: 0.9998)
# benign (368).png               → normal    (confidence: 0.5165)
# benign (369).png               → benign    (confidence: 0.9997)
# benign (37).png                → benign    (confidence: 0.9989)
# benign (370).png               → benign    (confidence: 0.9997)
# benign (371).png               → benign    (confidence: 0.9995)
# benign (372).png               → benign    (confidence: 0.5862)
# benign (373).png               → benign    (confidence: 0.5339)
# benign (374).png               → benign    (confidence: 0.9963)
# benign (375).png               → benign    (confidence: 0.9998)
# benign (376).png               → benign    (confidence: 0.9990)
# benign (377).png               → benign    (confidence: 0.9975)
# benign (378).png               → benign    (confidence: 1.0000)
# benign (379).png               → benign    (confidence: 0.9425)
# benign (38).png                → benign    (confidence: 1.0000)
# benign (380).png               → benign    (confidence: 0.9998)
# benign (381).png               → benign    (confidence: 0.9980)
# benign (382).png               → benign    (confidence: 1.0000)
# benign (383).png               → malignant (confidence: 0.9696)
# benign (384).png               → benign    (confidence: 0.9924)
# benign (385).png               → benign    (confidence: 0.9861)
# benign (386).png               → benign    (confidence: 1.0000)
# benign (387).png               → benign    (confidence: 0.9996)
# benign (388).png               → benign    (confidence: 0.9991)
# benign (389).png               → benign    (confidence: 1.0000)
# benign (39).png                → normal    (confidence: 0.9967)
# benign (390).png               → benign    (confidence: 0.9998)
# benign (391).png               → benign    (confidence: 0.9940)
# benign (392).png               → normal    (confidence: 0.9351)
# benign (393).png               → benign    (confidence: 1.0000)
# benign (394).png               → benign    (confidence: 0.9836)
# benign (395).png               → benign    (confidence: 0.9933)
# benign (396).png               → benign    (confidence: 0.9954)
# benign (397).png               → benign    (confidence: 1.0000)
# benign (398).png               → benign    (confidence: 0.9716)
# benign (399).png               → benign    (confidence: 0.9894)
# benign (4).png                 → benign    (confidence: 1.0000)
# benign (40).png                → benign    (confidence: 0.8052)
# benign (400).png               → benign    (confidence: 0.9989)
# benign (401).png               → benign    (confidence: 1.0000)
# benign (402).png               → malignant (confidence: 0.5524)
# benign (403).png               → benign    (confidence: 0.9995)
# benign (404).png               → benign    (confidence: 0.9993)
# benign (405).png               → benign    (confidence: 0.9861)
# benign (406).png               → benign    (confidence: 0.5614)
# benign (407).png               → benign    (confidence: 0.9949)
# benign (408).png               → benign    (confidence: 0.9938)
# benign (409).png               → benign    (confidence: 0.9995)
# benign (41).png                → benign    (confidence: 0.9885)
# benign (410).png               → benign    (confidence: 0.9999)
# benign (411).png               → benign    (confidence: 0.9907)
# benign (412).png               → benign    (confidence: 0.9989)
# benign (413).png               → benign    (confidence: 0.9387)
# benign (414).png               → benign    (confidence: 0.9960)
# benign (415).png               → benign    (confidence: 0.9987)
# benign (416).png               → benign    (confidence: 0.9916)
# benign (417).png               → benign    (confidence: 0.9983)
# benign (418).png               → benign    (confidence: 0.9918)
# benign (419).png               → benign    (confidence: 0.9997)
# benign (42).png                → malignant (confidence: 0.9731)
# benign (420).png               → benign    (confidence: 0.9994)
# benign (421).png               → malignant (confidence: 0.9784)
# benign (422).png               → normal    (confidence: 0.7975)
# benign (423).png               → benign    (confidence: 0.9998)
# benign (424).png               → benign    (confidence: 0.9991)
# benign (425).png               → benign    (confidence: 0.9938)
# benign (426).png               → benign    (confidence: 0.9979)
# benign (427).png               → benign    (confidence: 1.0000)
# benign (428).png               → benign    (confidence: 0.9989)
# benign (429).png               → benign    (confidence: 1.0000)
# benign (43).png                → benign    (confidence: 0.9975)
# benign (430).png               → benign    (confidence: 1.0000)
# benign (431).png               → benign    (confidence: 0.9997)
# benign (432).png               → benign    (confidence: 1.0000)
# benign (433).png               → malignant (confidence: 0.5531)
# benign (434).png               → benign    (confidence: 0.9998)
# benign (435).png               → benign    (confidence: 0.9783)
# benign (436).png               → benign    (confidence: 1.0000)
# benign (437).png               → normal    (confidence: 0.8441)
# benign (44).png                → benign    (confidence: 0.9996)
# benign (45).png                → benign    (confidence: 1.0000)
# benign (46).png                → benign    (confidence: 1.0000)
# benign (47).png                → benign    (confidence: 0.9941)
# benign (48).png                → benign    (confidence: 0.9987)
# benign (49).png                → benign    (confidence: 1.0000)
# benign (5).png                 → benign    (confidence: 1.0000)
# benign (50).png                → benign    (confidence: 0.9994)
# benign (51).png                → benign    (confidence: 1.0000)
# benign (52).png                → benign    (confidence: 1.0000)
# benign (53).png                → normal    (confidence: 0.6070)
# benign (54).png                → benign    (confidence: 0.9954)
# benign (55).png                → benign    (confidence: 0.9940)
# benign (56).png                → benign    (confidence: 0.9998)
# benign (57).png                → benign    (confidence: 0.9960)
# benign (58).png                → benign    (confidence: 0.9996)
# benign (59).png                → benign    (confidence: 0.9995)
# benign (6).png                 → benign    (confidence: 1.0000)
# benign (60).png                → benign    (confidence: 0.9996)
# benign (61).png                → benign    (confidence: 0.9970)
# benign (62).png                → benign    (confidence: 0.9980)
# benign (63).png                → benign    (confidence: 0.9962)
# benign (64).png                → benign    (confidence: 0.9930)
# benign (65).png                → benign    (confidence: 1.0000)
# benign (66).png                → benign    (confidence: 0.9992)
# benign (67).png                → benign    (confidence: 1.0000)
# benign (68).png                → benign    (confidence: 0.9999)
# benign (69).png                → benign    (confidence: 0.8026)
# benign (7).png                 → benign    (confidence: 0.9982)
# benign (70).png                → benign    (confidence: 0.9975)
# benign (71).png                → normal    (confidence: 0.7231)
# benign (72).png                → benign    (confidence: 1.0000)
# benign (73).png                → benign    (confidence: 0.9999)
# benign (74).png                → benign    (confidence: 0.9829)
# benign (75).png                → benign    (confidence: 0.9999)
# benign (76).png                → benign    (confidence: 0.9981)
# benign (77).png                → benign    (confidence: 0.9998)
# benign (78).png                → benign    (confidence: 1.0000)
# benign (79).png                → benign    (confidence: 0.9965)
# benign (8).png                 → benign    (confidence: 0.9996)
# benign (80).png                → benign    (confidence: 0.9998)
# benign (81).png                → benign    (confidence: 1.0000)
# benign (82).png                → benign    (confidence: 0.9990)
# benign (83).png                → benign    (confidence: 1.0000)
# benign (84).png                → benign    (confidence: 0.9470)
# benign (85).png                → benign    (confidence: 0.9123)
# benign (86).png                → benign    (confidence: 0.9999)
# benign (87).png                → benign    (confidence: 0.9999)
# benign (88).png                → benign    (confidence: 0.9996)
# benign (89).png                → benign    (confidence: 0.9996)
# benign (9).png                 → benign    (confidence: 0.9984)
# benign (90).png                → malignant (confidence: 0.9644)
# benign (91).png                → benign    (confidence: 0.9941)
# benign (92).png                → benign    (confidence: 1.0000)
# benign (93).png                → benign    (confidence: 0.9967)
# benign (94).png                → benign    (confidence: 0.9952)
# benign (95).png                → benign    (confidence: 0.6942)
# benign (96).png                → benign    (confidence: 0.9972)
# benign (97).png                → benign    (confidence: 1.0000)
# benign (98).png                → benign    (confidence: 0.9990)
# benign (99).png                → benign    (confidence: 1.0000)
# malignant (1).png              → malignant (confidence: 0.9872)
# malignant (10).png             → malignant (confidence: 0.9977)
# malignant (100).png            → benign    (confidence: 0.5043)
# malignant (101).png            → malignant (confidence: 0.9967)
# malignant (102).png            → malignant (confidence: 0.9998)
# malignant (103).png            → malignant (confidence: 0.9946)
# malignant (104).png            → malignant (confidence: 1.0000)
# malignant (105).png            → malignant (confidence: 0.9964)
# malignant (106).png            → malignant (confidence: 1.0000)
# malignant (107).png            → malignant (confidence: 0.9974)
# malignant (108).png            → malignant (confidence: 0.6503)
# malignant (109).png            → malignant (confidence: 0.9926)
# malignant (11).png             → malignant (confidence: 0.9980)
# malignant (110).png            → malignant (confidence: 0.9919)
# malignant (111).png            → malignant (confidence: 1.0000)
# malignant (112).png            → malignant (confidence: 0.9996)
# malignant (113).png            → malignant (confidence: 0.9996)
# malignant (114).png            → malignant (confidence: 1.0000)
# malignant (115).png            → malignant (confidence: 0.9994)
# malignant (116).png            → malignant (confidence: 0.9931)
# malignant (117).png            → malignant (confidence: 0.8956)
